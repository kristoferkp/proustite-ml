# %%
import cv2

from ultralytics import YOLO

# Load the YOLO model
model = YOLO("/Users/kristofer/Dev/proustite/proustite-ai/runs/detect/train/weights/best.onnx")

# Open the video file
video_path = "detect.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# Loading /Users/kristofer/Dev/proustite/proustite-ai/runs/detect/train/weights/best.onnx for ONNX Runtime inference...
# Using ONNX Runtime 1.23.2 with CPUExecutionProvider
#
# 0: 640x640 2 Balls, 1 Blue Goal, 49.2ms
# Speed: 2.3ms preprocess, 49.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 48.2ms
# Speed: 2.2ms preprocess, 48.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.3ms
# Speed: 0.9ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.6ms
# Speed: 1.0ms preprocess, 41.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 45.9ms
# Speed: 0.9ms preprocess, 45.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.6ms
# Speed: 0.9ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 46.0ms
# Speed: 0.9ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 40.6ms
# Speed: 0.9ms preprocess, 40.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.3ms
# Speed: 0.9ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.7ms
# Speed: 0.9ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.5ms
# Speed: 0.9ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.1ms
# Speed: 0.9ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.1ms
# Speed: 0.9ms preprocess, 41.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.5ms
# Speed: 0.9ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.9ms
# Speed: 0.9ms preprocess, 41.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.2ms
# Speed: 0.9ms preprocess, 42.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.9ms
# Speed: 0.9ms preprocess, 41.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 40.9ms
# Speed: 0.9ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.7ms
# Speed: 0.9ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.4ms
# Speed: 0.9ms preprocess, 41.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.9ms
# Speed: 0.9ms preprocess, 41.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 43.4ms
# Speed: 0.9ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.4ms
# Speed: 0.9ms preprocess, 41.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.0ms
# Speed: 0.9ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 40.9ms
# Speed: 0.9ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.9ms
# Speed: 0.9ms preprocess, 41.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 46.4ms
# Speed: 0.9ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.2ms
# Speed: 0.9ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.3ms
# Speed: 0.9ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.7ms
# Speed: 0.9ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.1ms
# Speed: 0.9ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.4ms
# Speed: 0.9ms preprocess, 41.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 40.3ms
# Speed: 0.9ms preprocess, 40.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 43.2ms
# Speed: 0.9ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 63.2ms
# Speed: 0.9ms preprocess, 63.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.3ms
# Speed: 1.1ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.2ms
# Speed: 0.9ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 40.4ms
# Speed: 1.0ms preprocess, 40.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.7ms
# Speed: 0.9ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal,
3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 40.9ms
# Speed: 0.9ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 47.9ms
# Speed: 0.9ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Balls, 1 Blue Goal, 47.3ms
# Speed: 1.6ms preprocess, 47.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 19
#      15 success, frame = cap.read()
#      17 if success:
#      18     # Run YOLO inference on the frame
# ---> 19     results = model(frame)
#      21     # Visualize the results on the frame
#      22     annotated_frame = results[0].plot()
#
# File ~/Dev/proustite/proustite-ai/.venv/lib/python3.13/site-packages/ultralytics/engine/model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     149 def __call__(
#     150     self,
#     151     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     152     stream: bool = False,
#     153     **kwargs: Any,
#     154 ) -> list:
#     155     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
#     157     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    175         ...     print(f"Detected {len(r)} objects in image")
#     176     """
# --> 177     return self.predict(source, stream, **kwargs)
#
# File ~/Dev/proustite/proustite-ai/.venv/lib/python3.13/site-packages/ultralytics/engine/model.py:536, in Model.predict(self, source, stream, predictor, **kwargs)
#     534 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535     self.predictor.set_prompts(prompts)
# --> 536 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Dev/proustite/proustite-ai/.venv/lib/python3.13/site-packages/ultralytics/engine/predictor.py:225, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     223     return self.stream_inference(source, model, *args, **kwargs)
#     224 else:
# --> 225     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/Dev/proustite/proustite-ai/.venv/lib/python3.13/site-packages/torch/utils/_contextlib.py:38, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      35 try:
#      36     # Issuing `None` to a generator fires it up
#      37     with ctx_factory():
# ---> 38         response = gen.send(None)
#      40     while True:
#      41         try:
#      42             # Forward the response to our caller and get its next request
#
# File ~/Dev/proustite/proustite-ai/.venv/lib/python3.13/site-packages/ultralytics/engine/predictor.py:330, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     328 # Inference
#     329 with profilers[1]:
# --> 330     preds = self.inference(im, *args, **kwargs)
#     331     if self.args.embed:
#     332         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/Dev/proustite/proustite-ai/.venv/lib/python3.13/site-packages/ultralytics/engine/predictor.py:182, in BasePredictor.inference(self, im, *args, **kwargs)
#     176 """Run inference on a given image using the specified model and arguments."""
#     177 visualize = (
#     178     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     179     if self.args.visualize and (not self.source_type.tensor)
#     180     else False
#     181 )
# --> 182 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/Dev/proustite/proustite-ai/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Dev/proustite/proustite-ai/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Dev/proustite/proustite-ai/.venv/lib/python3.13/site-packages/ultralytics/nn/autobackend.py:724, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     722 else:
#     723     im = im.cpu().numpy()  # torch to numpy
# --> 724     y = self.session.run(self.output_names, {self.session.get_inputs()[0].name: im})
#     725 if self.imx:
#     726     if self.task == "detect":
#     727         # boxes, conf, cls
#
# File ~/Dev/proustite/proustite-ai/.venv/lib/python3.13/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:287, in Session.run(self, output_names, input_feed, run_options)
#     285     output_names = [output.name for output in self._outputs_meta]
#     286 try:
# --> 287     return self._sess.run(output_names, input_feed, run_options)
#     288 except C.EPFail as err:
#     289     if self._enable_fallback:
#
# KeyboardInterrupt:
